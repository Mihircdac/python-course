# %% [markdown]
# ---------------------------
# Working around columns
# ---------------------------
#
# 1. Changing column names and formatting:
#    a. Renaming columns:
#       - Renaming columns using `rename()` method
#       - Renaming columns using dictionary mapping
#    b. Reformatting column names:
#       - Converting column names to lowercase
#       - Replacing spaces from column names with underscores
#       - Applying custom formatting to column names

# %%
### Reading from excel
### py -m pip install openpyxl
import pandas as pd
df = pd.read_excel(r"C:\Users\duasp\Desktop\python course\Day12\customer_order_data.xlsx")
df
# Out:
#    Order ID          Product Customer ID  Is Prime  Quantity  Price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#   Order DatetimeTZNaive Order Status Shipping Address Order Period
# 0   2022-01-01 08:00:00      Pending      123 Main St      2022-01
# 1   2022-01-02 08:00:00      Shipped       456 Elm St      2022-02
# 2   2022-01-03 08:00:00    Delivered       789 Oak St      2022-03
# 3   2022-01-04 08:00:00      Pending      321 Pine St      2022-04
# 4   2022-01-05 08:00:00      Shipped     654 Maple St      2022-05

# %% [markdown]
# In pandas, the columns attribute of a DataFrame object represents the column labels or names of the DataFrame. It is an index-like object that provides access to the column labels and allows you to perform various operations on the columns.When you access df.columns, you are retrieving the column labels of the DataFrame as an Index object

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Customer ID', 'Is Prime', 'Quantity', 'Price',
#        'Order DatetimeTZNaive', 'Order Status', 'Shipping Address',
#        'Order Period'],
#       dtype='object')

# %%
df.columns = ['column1', 'column2', 'column3', 'column4', 'column5', 'column6','column7', 'column8', 'column9','column10']
df
# Out:
#    column1          column2 column3  column4  column5  column6  \
# 0     1001           Widget    C001     True       10     9.99
# 1     1002           Gadget    C002    False        5    19.99
# 2     1003      Thingamajig    C003     True        8    14.99
# 3     1004           Doodad    C004    False        3     7.99
# 4     1005  Whatchamacallit    C005     True       12    24.99
#
#               column7    column8       column9 column10
# 0 2022-01-01 08:00:00    Pending   123 Main St  2022-01
# 1 2022-01-02 08:00:00    Shipped    456 Elm St  2022-02
# 2 2022-01-03 08:00:00  Delivered    789 Oak St  2022-03
# 3 2022-01-04 08:00:00    Pending   321 Pine St  2022-04
# 4 2022-01-05 08:00:00    Shipped  654 Maple St  2022-05

# %%
df.columns = ['Order ID', 'Product', 'Customer ID', 'Is Prime', 'Quantity', 'Price',
            'Order DatetimeTZNaive', 'Order Status', 'Shipping Address',
            'Order Period']

df
# Out:
#    Order ID          Product Customer ID  Is Prime  Quantity  Price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#   Order DatetimeTZNaive Order Status Shipping Address Order Period
# 0   2022-01-01 08:00:00      Pending      123 Main St      2022-01
# 1   2022-01-02 08:00:00      Shipped       456 Elm St      2022-02
# 2   2022-01-03 08:00:00    Delivered       789 Oak St      2022-03
# 3   2022-01-04 08:00:00      Pending      321 Pine St      2022-04
# 4   2022-01-05 08:00:00      Shipped     654 Maple St      2022-05

# %%
# Renaming columns using rename() method
df = df.rename(columns={'Order DatetimeTZNaive': 'Order date', 'Order Period': 'Order Year'})
df
# Out:
#    Order ID          Product Customer ID  Is Prime  Quantity  Price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            Order date Order Status Shipping Address Order Year
# 0 2022-01-01 08:00:00      Pending      123 Main St    2022-01
# 1 2022-01-02 08:00:00      Shipped       456 Elm St    2022-02
# 2 2022-01-03 08:00:00    Delivered       789 Oak St    2022-03
# 3 2022-01-04 08:00:00      Pending      321 Pine St    2022-04
# 4 2022-01-05 08:00:00      Shipped     654 Maple St    2022-05

# %%
# Renaming columns using dictionary mapping
column_mapping = {'Order Year': 'Order Month', 'Order Status': 'Status'}
df = df.rename(columns=column_mapping)
df
# Out:
#    Order ID          Product Customer ID  Is Prime  Quantity  Price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            Order date     Status Shipping Address Order Month
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05

# %% [markdown]
# In pandas, an accessor is like a toolbox that contains specific tools for working with different types of data. Each accessor is designed to handle a specific type of data or domain.
#
# For example, the .str accessor is like a toolbox for working with strings. It provides tools and functions that are useful for manipulating and analyzing text data. You can use it to perform operations like extracting substrings, replacing text, or checking for specific patterns in your string data

# %%
# Converting column names to lowercase and replacing space with _
df.columns = df.columns.str.lower().str.replace(' ','_')
df.columns
# Out:
# Index(['order_id', 'product', 'customer_id', 'is_prime', 'quantity', 'price',
#        'order_date', 'status', 'shipping_address', 'order_month'],
#       dtype='object')

# %%
# Applying custom formatting to column names
temp_list = []
for cur_val in df.columns:
    temp_list.append( 'org_'+ cur_val )
   
df.columns = temp_list 
df
# Out:
#    org_order_id      org_product org_customer_id  org_is_prime  org_quantity  \
# 0          1001           Widget            C001          True            10
# 1          1002           Gadget            C002         False             5
# 2          1003      Thingamajig            C003          True             8
# 3          1004           Doodad            C004         False             3
# 4          1005  Whatchamacallit            C005          True            12
#
#    org_price      org_order_date org_status org_shipping_address  \
# 0       9.99 2022-01-01 08:00:00    Pending          123 Main St
# 1      19.99 2022-01-02 08:00:00    Shipped           456 Elm St
# 2      14.99 2022-01-03 08:00:00  Delivered           789 Oak St
# 3       7.99 2022-01-04 08:00:00    Pending          321 Pine St
# 4      24.99 2022-01-05 08:00:00    Shipped         654 Maple St
#
#   org_order_month
# 0         2022-01
# 1         2022-02
# 2         2022-03
# 3         2022-04
# 4         2022-05

# %% [markdown]
# 2. Adding columns:
#
#    a. Adding new columns:
#       - Creating a new column with a constant value
#       - Creating a new column based on existing columns using arithmetic operations
#       - Creating a new column using conditional logic

# %%
# lets read the dataframe by slicing off the organisation name that we added in the earlier step
df.columns = df.columns.str.slice_replace(0,4,'') 
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05

# %%
#Creating a new column with a constant value:
df['payment_method'] = 'Credit Card'
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03    Credit Card
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04    Credit Card
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05    Credit Card

# %%
# Creating a new column based on existing columns using arithmetic operations:
df['total_price'] = df['quantity'] * df['price']
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03    Credit Card
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04    Credit Card
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05    Credit Card
#
#    total_price
# 0        99.90
# 1        99.95
# 2       119.92
# 3        23.97
# 4       299.88

# %%
#Creating a new column using conditional logic:


# def my_check(i):
#         if i>10:
#             return True
#         else:
#             return False

# df['is_discounted_custom_func']= df['price'].apply(my_check)        
# df

import numpy as np
df['discounted'] = np.where(df['price'] > 10, True, False)
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03    Credit Card
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04    Credit Card
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05    Credit Card
#
#    total_price  discounted
# 0        99.90       False
# 1        99.95        True
# 2       119.92        True
# 3        23.97       False
# 4       299.88        True

# %%
#Creating a new column using conditional logic having multiple conditions and multiple values :
# Define the conditions and corresponding values for the new column
conditions = [df['status'] == 'Pending',
              df['status'] == 'Shipped',
              df['status'] == 'Delivered']
values = ['Processing', 'In Transit', 'Completed']

# Create the new column using np.select()
df['category'] = np.select(conditions, values, 'Unknown')

df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03    Credit Card
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04    Credit Card
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05    Credit Card
#
#    total_price  discounted    category
# 0        99.90       False  Processing
# 1        99.95        True  In Transit
# 2       119.92        True   Completed
# 3        23.97       False  Processing
# 4       299.88        True  In Transit

# %% [markdown]
#    Prerequiste : Subsetting of columns/rows from a dataframe using .loc[row_indexer,col_indexer]
#
#    2.1 updating columns values :
#       - Updating values in a specific column based on conditions
#       - Updating values in multiple columns based on conditions

# %%
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03    Credit Card
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04    Credit Card
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05    Credit Card
#
#    total_price  discounted    category
# 0        99.90       False  Processing
# 1        99.95        True  In Transit
# 2       119.92        True   Completed
# 3        23.97       False  Processing
# 4       299.88        True  In Transit

# %%
# accessing a single column 
df['customer_id']
# Out:
# 0    C001
# 1    C002
# 2    C003
# 3    C004
# 4    C005
# Name: customer_id, dtype: object

# %%
# accessing multiple columns 
df[['customer_id','order_id','product']]
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03    Credit Card
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04    Credit Card
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05    Credit Card
#
#    total_price  discounted    category
# 0        99.90       False  Processing
# 1        99.95        True  In Transit
# 2       119.92        True   Completed
# 3        23.97       False  Processing
# 4       299.88        True  In Transit

# %%
df

# %%
# Select a single row by label
# .loc[row_indexer,col_indexer] col_indexer is optional 
row_indexer = 2
col_indexer = ['order_id','product','customer_id','is_prime','quantity','price','order_date','status','shipping_address','order_month','payment_method','total_price','discounted','category']
selected_row = df.loc[row_indexer,col_indexer]
selected_row
# Out:
# order_id                           1003
# product                     Thingamajig
# customer_id                        C003
# is_prime                           True
# quantity                              8
# price                             14.99
# order_date          2022-01-03 08:00:00
# status                        Delivered
# shipping_address             789 Oak St
# order_month                     2022-03
# payment_method              Credit Card
# total_price                      119.92
# discounted                         True
# category                      Completed
# Name: 2, dtype: object

# %%
# Select multiple rows by labels

# Create a list of index labels
row_indexer = [0, 1, 2]
col_indexer = ['order_id','product','customer_id','is_prime','quantity','price','order_date','status','shipping_address','order_month','payment_method','total_price','discounted','category']

# Use the list of labels to select rows with matching index values
selected_row = df.loc[row_indexer,col_indexer]

# Print the selected rows
selected_row
# Out:
#    order_id      product customer_id  is_prime  quantity  price  \
# 0      1001       Widget        C001      True        10   9.99
# 1      1002       Gadget        C002     False         5  19.99
# 2      1003  Thingamajig        C003      True         8  14.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03    Credit Card
#
#    total_price  discounted    category
# 0        99.90       False  Processing
# 1        99.95        True  In Transit
# 2       119.92        True   Completed

# %%
# Select a range of rows using slice object with labels
row_indexer = slice(0,2)

col_indexer = ['order_id','product','customer_id','is_prime','quantity','price','order_date','status','shipping_address','order_month','payment_method','total_price','discounted','category']

selected_rows = df.loc[row_indexer,col_indexer]
selected_rows
# Out:
#    order_id      product customer_id  is_prime  quantity  price  \
# 0      1001       Widget        C001      True        10   9.99
# 1      1002       Gadget        C002     False         5  19.99
# 2      1003  Thingamajig        C003      True         8  14.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03    Credit Card
#
#    total_price  discounted    category
# 0        99.90       False  Processing
# 1        99.95        True  In Transit
# 2       119.92        True   Completed

# %%
# Select rows based on a boolean condition (boolean array)
row_indexer = [True, False, True, False, True]

col_indexer = ['order_id','product','customer_id','is_prime','quantity','price','order_date','status','shipping_address','order_month','payment_method','total_price','discounted','category']

selected_rows = df.loc[row_indexer,col_indexer]
selected_rows
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03    Credit Card
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05    Credit Card
#
#    total_price  discounted    category
# 0        99.90       False  Processing
# 2       119.92        True   Completed
# 4       299.88        True  In Transit

# %%
# Select rows based on a boolean condition (boolean array constructed using a condition)

row_indexer = df["product"].isin(['Widget','Thingamajig','Whatchamacallit'])
col_indexer = ['order_id','product','customer_id','is_prime','quantity','price','order_date','status','shipping_address','order_month','payment_method','total_price','discounted','category']

selected_rows = df.loc[row_indexer,col_indexer]
selected_rows
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03    Credit Card
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05    Credit Card
#
#    total_price  discounted    category
# 0        99.90       False  Processing
# 2       119.92        True   Completed
# 4       299.88        True  In Transit

# %% [markdown]
#    2.1 updating, and removing columns:
#
#    a. Updating column values:
#       - Updating values in a specific column unconditionally
#       - Updating values in multiple columns unconditionally
#       - Updating values in a specific column based on conditions
#       - Updating values in multiple columns based on conditions
#
#    b. Removing columns:
#       - Dropping a single column using `drop()` method
#       - Dropping multiple columns at once
#       - Removing columns based on conditions ( column containing all nulls)

# %%
df

# %%
# - Updating values in a specific column unconditionally
df["payment_method"] = 'Cash'
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004     False         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01           Cash
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02           Cash
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03           Cash
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04           Cash
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05           Cash
#
#    total_price  discounted    category
# 0        99.90       False  Processing
# 1        99.95        True  In Transit
# 2       119.92        True   Completed
# 3        23.97       False  Processing
# 4       299.88        True  In Transit

# %%
# - Updating values in multiple columns unconditionally
df[['is_prime','payment_method']] = [True,'Cheque']
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002      True         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004      True         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01         Cheque
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02         Cheque
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03         Cheque
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04         Cheque
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05         Cheque
#
#    total_price  discounted    category
# 0        99.90       False  Processing
# 1        99.95        True  In Transit
# 2       119.92        True   Completed
# 3        23.97       False  Processing
# 4       299.88        True  In Transit

# %%
# - Updating values in a specific column based on conditions
row_indexer = df['customer_id'] == 'C001'
column_indexer = 'payment_method'
values_indexer = 'Credit Card'

df.loc[row_indexer,column_indexer] = values_indexer
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002      True         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004      True         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02         Cheque
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03         Cheque
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04         Cheque
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05         Cheque
#
#    total_price  discounted    category
# 0        99.90       False  Processing
# 1        99.95        True  In Transit
# 2       119.92        True   Completed
# 3        23.97       False  Processing
# 4       299.88        True  In Transit

# %%
# - Updating values in multiple columns based on conditions
row_indexer = df['customer_id'] == 'C002'
column_indexer = ['payment_method','is_prime']
values_indexer = ['Cash',False]

df.loc[row_indexer,column_indexer] = values_indexer
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004      True         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02           Cash
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03         Cheque
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04         Cheque
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05         Cheque
#
#    total_price  discounted    category
# 0        99.90       False  Processing
# 1        99.95        True  In Transit
# 2       119.92        True   Completed
# 3        23.97       False  Processing
# 4       299.88        True  In Transit

# %%
#   - Dropping a single column using `drop()` method
df_backup = df
columns_to_drop = 'category'    
df = df.drop(columns = columns_to_drop, errors = 'ignore' )
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004      True         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02           Cash
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03         Cheque
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04         Cheque
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05         Cheque
#
#    total_price  discounted
# 0        99.90       False
# 1        99.95        True
# 2       119.92        True
# 3        23.97       False
# 4       299.88        True

# %%
#   - Dropping multiple columns at once
    
columns_to_drop = ['total_price','discounted']    
df = df.drop(columns = columns_to_drop, errors = 'ignore'  )
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004      True         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02           Cash
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03         Cheque
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04         Cheque
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05         Cheque

# %%
df['none_column'] = None
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004      True         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method  \
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02           Cash
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03         Cheque
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04         Cheque
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05         Cheque
#
#   none_column
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None

# %%
#   - Removing columns based on conditions ( column containing all nulls)
df = df.dropna(axis = 'columns' , how = 'all')
df
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 1      1002           Gadget        C002     False         5  19.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004      True         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 1 2022-01-02 08:00:00    Shipped       456 Elm St     2022-02           Cash
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03         Cheque
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04         Cheque
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05         Cheque

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5 non-null      int64
#  1   product           5 non-null      object
#  2   customer_id       5 non-null      object
#  3   is_prime          5 non-null      bool
#  4   quantity          5 non-null      int64
#  5   price             5 non-null      float64
#  6   order_date        5 non-null      datetime64[ns]
#  7   status            5 non-null      object
#  8   shipping_address  5 non-null      object
#  9   order_month       5 non-null      object
#  10  payment_method    5 non-null      object
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 537.0+ bytes

# %%
df.describe()
# Out:
#           order_id   quantity      price           order_date
# count     5.000000   5.000000   5.000000                    5
# mean   1003.000000   7.600000  15.590000  2022-01-03 08:00:00
# min    1001.000000   3.000000   7.990000  2022-01-01 08:00:00
# 25%    1002.000000   5.000000   9.990000  2022-01-02 08:00:00
# 50%    1003.000000   8.000000  14.990000  2022-01-03 08:00:00
# 75%    1004.000000  10.000000  19.990000  2022-01-04 08:00:00
# max    1005.000000  12.000000  24.990000  2022-01-05 08:00:00
# std       1.581139   3.646917   7.021396                  NaN

# %%
df.head(1)
# Out:
#    order_id product customer_id  is_prime  quantity  price  \
# 0      1001  Widget        C001      True        10   9.99
#
#            order_date   status shipping_address order_month payment_method
# 0 2022-01-01 08:00:00  Pending      123 Main St     2022-01    Credit Card

# %%
df.tail(2)
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 3      1004           Doodad        C004      True         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date   status shipping_address order_month payment_method
# 3 2022-01-04 08:00:00  Pending      321 Pine St     2022-04         Cheque
# 4 2022-01-05 08:00:00  Shipped     654 Maple St     2022-05         Cheque

# %%
# give me all rows that have statius as pending
df.query("status=='Pending'")

# or

row_indexer = df['status'] == 'Pending'
df.loc[row_indexer]
# Out:
#    order_id product customer_id  is_prime  quantity  price  \
# 0      1001  Widget        C001      True        10   9.99
# 3      1004  Doodad        C004      True         3   7.99
#
#            order_date   status shipping_address order_month payment_method
# 0 2022-01-01 08:00:00  Pending      123 Main St     2022-01    Credit Card
# 3 2022-01-04 08:00:00  Pending      321 Pine St     2022-04         Cheque

# %%
# # give me all rows that have statius as pending and payment_method is Cheque
# df.query("status=='Pending' and payment_method == 'Cheque'")

# # or


row_indexer = (df['status'] == 'Pending') & (df["payment_method"] == 'Cheque')
df.loc[row_indexer]
# Out:
#    order_id product customer_id  is_prime  quantity  price  \
# 3      1004  Doodad        C004      True         3   7.99
#
#            order_date   status shipping_address order_month payment_method
# 3 2022-01-04 08:00:00  Pending      321 Pine St     2022-04         Cheque

# %%
# # give me all rows that have statius as pending and payment_method is Cheque
# df.query("status=='Pending' or payment_method == 'Cheque'")

# # or

row_indexer = (df['status'] == 'Pending') | (df["payment_method"] == 'Cheque')
df.loc[row_indexer]
# Out:
#    order_id          product customer_id  is_prime  quantity  price  \
# 0      1001           Widget        C001      True        10   9.99
# 2      1003      Thingamajig        C003      True         8  14.99
# 3      1004           Doodad        C004      True         3   7.99
# 4      1005  Whatchamacallit        C005      True        12  24.99
#
#            order_date     status shipping_address order_month payment_method
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03         Cheque
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04         Cheque
# 4 2022-01-05 08:00:00    Shipped     654 Maple St     2022-05         Cheque

# %%
# give me all rows that have statius as pending or Delivered
df.query("status in ('Pending','Delivered') ")

# # or

row_indexer = (df['status'].isin(['Pending','Delivered']) )
df.loc[row_indexer]
# Out:
#    order_id      product customer_id  is_prime  quantity  price  \
# 0      1001       Widget        C001      True        10   9.99
# 2      1003  Thingamajig        C003      True         8  14.99
# 3      1004       Doodad        C004      True         3   7.99
#
#            order_date     status shipping_address order_month payment_method
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03         Cheque
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04         Cheque

# %%
df.query("status in ('Pending','Delivered') ").sort_values(by = 'order_date' , ascending= False)
# Out:
#    order_id      product customer_id  is_prime  quantity  price  \
# 3      1004       Doodad        C004      True         3   7.99
# 2      1003  Thingamajig        C003      True         8  14.99
# 0      1001       Widget        C001      True        10   9.99
#
#            order_date     status shipping_address order_month payment_method
# 3 2022-01-04 08:00:00    Pending      321 Pine St     2022-04         Cheque
# 2 2022-01-03 08:00:00  Delivered       789 Oak St     2022-03         Cheque
# 0 2022-01-01 08:00:00    Pending      123 Main St     2022-01    Credit Card

# %%
temp_df = df.query("status in ('Pending','Delivered') ").sort_values(by = 'order_date' , ascending= False)

df.set_index('order_id').join(temp_df.set_index('order_id'),on= 'order_id',how= 'left',lsuffix='_org',rsuffix='_temp')
# Out:
#               product_org customer_id_org  is_prime_org  quantity_org  \
# order_id
# 1001               Widget            C001          True            10
# 1002               Gadget            C002         False             5
# 1003          Thingamajig            C003          True             8
# 1004               Doodad            C004          True             3
# 1005      Whatchamacallit            C005          True            12
#
#           price_org      order_date_org status_org shipping_address_org  \
# order_id
# 1001           9.99 2022-01-01 08:00:00    Pending          123 Main St
# 1002          19.99 2022-01-02 08:00:00    Shipped           456 Elm St
# 1003          14.99 2022-01-03 08:00:00  Delivered           789 Oak St
# 1004           7.99 2022-01-04 08:00:00    Pending          321 Pine St
# 1005          24.99 2022-01-05 08:00:00    Shipped         654 Maple St
#
#          order_month_org payment_method_org product_temp customer_id_temp  \
# order_id
# 1001             2022-01        Credit Card       Widget             C001
# 1002             2022-02               Cash          NaN              NaN
# 1003             2022-03             Cheque  Thingamajig             C003
# 1004             2022-04             Cheque       Doodad             C004
# 1005             2022-05             Cheque          NaN              NaN
#
#          is_prime_temp  quantity_temp  price_temp     order_date_temp  \
# order_id
# 1001              True           10.0        9.99 2022-01-01 08:00:00
# 1002               NaN            NaN         NaN                 NaT
# 1003              True            8.0       14.99 2022-01-03 08:00:00
# 1004              True            3.0        7.99 2022-01-04 08:00:00
# 1005               NaN            NaN         NaN                 NaT
#
#          status_temp shipping_address_temp order_month_temp  \
# order_id
# 1001         Pending           123 Main St          2022-01
# 1002             NaN                   NaN              NaN
# 1003       Delivered            789 Oak St          2022-03
# 1004         Pending           321 Pine St          2022-04
# 1005             NaN                   NaN              NaN
#
#          payment_method_temp
# order_id
# 1001             Credit Card
# 1002                     NaN
# 1003                  Cheque
# 1004                  Cheque
# 1005                     NaN

# %%
temp_df = df.query("status in ('Pending','Delivered') ").sort_values(by = 'order_date' , ascending= False)

df.set_index('order_id').join(temp_df.set_index('order_id'),on= 'order_id',how= 'right',lsuffix='_org',rsuffix='_temp')
# Out:
#           product_org customer_id_org  is_prime_org  quantity_org  price_org  \
# order_id
# 1004           Doodad            C004          True             3       7.99
# 1003      Thingamajig            C003          True             8      14.99
# 1001           Widget            C001          True            10       9.99
#
#               order_date_org status_org shipping_address_org order_month_org  \
# order_id
# 1004     2022-01-04 08:00:00    Pending          321 Pine St         2022-04
# 1003     2022-01-03 08:00:00  Delivered           789 Oak St         2022-03
# 1001     2022-01-01 08:00:00    Pending          123 Main St         2022-01
#
#          payment_method_org product_temp customer_id_temp  is_prime_temp  \
# order_id
# 1004                 Cheque       Doodad             C004           True
# 1003                 Cheque  Thingamajig             C003           True
# 1001            Credit Card       Widget             C001           True
#
#           quantity_temp  price_temp     order_date_temp status_temp  \
# order_id
# 1004                  3        7.99 2022-01-04 08:00:00     Pending
# 1003                  8       14.99 2022-01-03 08:00:00   Delivered
# 1001                 10        9.99 2022-01-01 08:00:00     Pending
#
#          shipping_address_temp order_month_temp payment_method_temp
# order_id
# 1004               321 Pine St          2022-04              Cheque
# 1003                789 Oak St          2022-03              Cheque
# 1001               123 Main St          2022-01         Credit Card

# %%
temp_df = df.query("status in ('Pending','Delivered') ").sort_values(by = 'order_date' , ascending= False)

df.set_index('order_id').join(temp_df.set_index('order_id'),on= 'order_id',how= 'inner',lsuffix='_org',rsuffix='_temp')
# Out:
#           product_org customer_id_org  is_prime_org  quantity_org  price_org  \
# order_id
# 1001           Widget            C001          True            10       9.99
# 1003      Thingamajig            C003          True             8      14.99
# 1004           Doodad            C004          True             3       7.99
#
#               order_date_org status_org shipping_address_org order_month_org  \
# order_id
# 1001     2022-01-01 08:00:00    Pending          123 Main St         2022-01
# 1003     2022-01-03 08:00:00  Delivered           789 Oak St         2022-03
# 1004     2022-01-04 08:00:00    Pending          321 Pine St         2022-04
#
#          payment_method_org product_temp customer_id_temp  is_prime_temp  \
# order_id
# 1001            Credit Card       Widget             C001           True
# 1003                 Cheque  Thingamajig             C003           True
# 1004                 Cheque       Doodad             C004           True
#
#           quantity_temp  price_temp     order_date_temp status_temp  \
# order_id
# 1001                 10        9.99 2022-01-01 08:00:00     Pending
# 1003                  8       14.99 2022-01-03 08:00:00   Delivered
# 1004                  3        7.99 2022-01-04 08:00:00     Pending
#
#          shipping_address_temp order_month_temp payment_method_temp
# order_id
# 1001               123 Main St          2022-01         Credit Card
# 1003                789 Oak St          2022-03              Cheque
# 1004               321 Pine St          2022-04              Cheque

# %%
# delete rows where status is pending and payment_method is cash 
df = df.query("status != 'pending' and payment_method != 'Cash'")
df
# Out:
#            order_id          product customer_id  is_prime  quantity  price  \
# status
# Delivered      1003      Thingamajig        C003      True         8  14.99
# Shipped        1005  Whatchamacallit        C005      True        12  24.99
#
#                    order_date shipping_address order_month payment_method
# status
# Delivered 2022-01-03 08:00:00       789 Oak St     2022-03         Cheque
# Shipped   2022-01-05 08:00:00     654 Maple St     2022-05         Cheque
